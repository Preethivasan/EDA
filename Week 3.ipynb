# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\preet\OneDrive\Desktop\Datasets\Shopify Dataset.csv")

# %%
df.head()
# Out:
#                         date   open   high    low  close  adj_close     volume
# 0  2015-05-21 00:00:00-04:00  2.800  2.874  2.411  2.568      2.568  123039000
# 1  2015-05-22 00:00:00-04:00  2.607  3.110  2.600  2.831      2.831   28412000
# 2  2015-05-26 00:00:00-04:00  2.980  3.034  2.908  2.965      2.965    8202000
# 3  2015-05-27 00:00:00-04:00  3.067  3.081  2.700  2.750      2.750    7976000
# 4  2015-05-28 00:00:00-04:00  2.755  2.774  2.648  2.745      2.745    4000000

# %%
df.tail()
# Out:
#                            date       open       high        low      close  \
# 2464  2025-03-10 00:00:00-04:00  96.070000  96.186996  91.690002  92.750000
# 2465  2025-03-11 00:00:00-04:00  92.750000  95.109001  91.150002  92.949997
# 2466  2025-03-12 00:00:00-04:00  96.669998  99.135002  95.290001  96.529999
# 2467  2025-03-13 00:00:00-04:00  95.169998  95.529999  89.099998  90.589996
# 2468  2025-03-14 00:00:00-04:00  94.610001  95.830002  93.059998  94.849998
#
#       adj_close    volume
# 2464  92.750000  16385300
# 2465  92.949997  12127100
# 2466  96.529999   8531900
# 2467  90.589996  11076400
# 2468  94.849998   7060700

# %%
df.describe()
# Out:
#               open         high          low        close    adj_close  \
# count  2469.000000  2469.000000  2469.000000  2469.000000  2469.000000
# mean     48.464345    49.505495    47.347795    48.456613    48.456613
# std      43.633916    44.470235    42.642546    43.573362    43.573362
# min       1.939000     1.985000     1.848000     1.933000     1.933000
# 25%      10.479000    10.635000    10.275000    10.450000    10.450000
# 50%      35.640999    36.879002    34.655998    35.874001    35.874001
# 75%      76.080002    77.169998    74.589996    75.800003    75.800003
# max     171.800003   176.291794   168.509506   169.059998   169.059998
#
#              volume
# count  2.469000e+03
# mean   1.657049e+07
# std    1.436909e+07
# min    1.039000e+06
# 25%    8.098000e+06
# 50%    1.275860e+07
# 75%    2.060200e+07
# max    2.089590e+08

# %%
df.shape
# Out:
# (2469, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2469 entries, 0 to 2468
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2469 non-null   object
#  1   open       2469 non-null   float64
#  2   high       2469 non-null   float64
#  3   low        2469 non-null   float64
#  4   close      2469 non-null   float64
#  5   adj_close  2469 non-null   float64
#  6   volume     2469 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 135.1+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2469, step=1)

# %%
df["date"] = pd.to_datetime(df["date"], utc = True).dt.date
df
# Out:
#             date       open       high        low      close  adj_close  \
# 0     2015-05-21   2.800000   2.874000   2.411000   2.568000   2.568000
# 1     2015-05-22   2.607000   3.110000   2.600000   2.831000   2.831000
# 2     2015-05-26   2.980000   3.034000   2.908000   2.965000   2.965000
# 3     2015-05-27   3.067000   3.081000   2.700000   2.750000   2.750000
# 4     2015-05-28   2.755000   2.774000   2.648000   2.745000   2.745000
# ...          ...        ...        ...        ...        ...        ...
# 2464  2025-03-10  96.070000  96.186996  91.690002  92.750000  92.750000
# 2465  2025-03-11  92.750000  95.109001  91.150002  92.949997  92.949997
# 2466  2025-03-12  96.669998  99.135002  95.290001  96.529999  96.529999
# 2467  2025-03-13  95.169998  95.529999  89.099998  90.589996  90.589996
# 2468  2025-03-14  94.610001  95.830002  93.059998  94.849998  94.849998
#
#          volume
# 0     123039000
# 1      28412000
# 2       8202000
# 3       7976000
# ...

# %%
df.set_index(df["date"])
# Out:
#                   date       open       high        low      close  adj_close  \
# date
# 2015-05-21  2015-05-21   2.800000   2.874000   2.411000   2.568000   2.568000
# 2015-05-22  2015-05-22   2.607000   3.110000   2.600000   2.831000   2.831000
# 2015-05-26  2015-05-26   2.980000   3.034000   2.908000   2.965000   2.965000
# 2015-05-27  2015-05-27   3.067000   3.081000   2.700000   2.750000   2.750000
# 2015-05-28  2015-05-28   2.755000   2.774000   2.648000   2.745000   2.745000
# ...                ...        ...        ...        ...        ...        ...
# 2025-03-10  2025-03-10  96.070000  96.186996  91.690002  92.750000  92.750000
# 2025-03-11  2025-03-11  92.750000  95.109001  91.150002  92.949997  92.949997
# 2025-03-12  2025-03-12  96.669998  99.135002  95.290001  96.529999  96.529999
# 2025-03-13  2025-03-13  95.169998  95.529999  89.099998  90.589996  90.589996
# 2025-03-14  2025-03-14  94.610001  95.830002  93.059998  94.849998  94.849998
#
#                volume
# ...

# %%
df.isnull().sum()
# Out:
# date         0
# open         0
# high         0
# low          0
# close        0
# adj_close    0
# volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#             date       open       high        low      close  adj_close  \
# 0     2015-05-21   2.800000   2.874000   2.411000   2.568000   2.568000
# 1     2015-05-22   2.607000   3.110000   2.600000   2.831000   2.831000
# 2     2015-05-26   2.980000   3.034000   2.908000   2.965000   2.965000
# 3     2015-05-27   3.067000   3.081000   2.700000   2.750000   2.750000
# 4     2015-05-28   2.755000   2.774000   2.648000   2.745000   2.745000
# ...          ...        ...        ...        ...        ...        ...
# 2464  2025-03-10  96.070000  96.186996  91.690002  92.750000  92.750000
# 2465  2025-03-11  92.750000  95.109001  91.150002  92.949997  92.949997
# 2466  2025-03-12  96.669998  99.135002  95.290001  96.529999  96.529999
# 2467  2025-03-13  95.169998  95.529999  89.099998  90.589996  90.589996
# 2468  2025-03-14  94.610001  95.830002  93.059998  94.849998  94.849998
#
#          volume
# 0     123039000
# 1      28412000
# 2       8202000
# 3       7976000
# ...

# %%
df["Daily_Price_Change"] = df["close"] - df["open"]

# %%
df["Daily_Return"] = ((df["close"] - df["open"]) / df["open"]) * 100

# %%
df["Daily_Return"] = df["Daily_Return"].round(2)

# %%
print(df["volume"].mean())
# Out:
# 16570491.778047793

# %%
print(df["volume"].max())
# Out:
# 208959000

# %%
print(df["volume"].min())
# Out:
# 1039000

# %%
print(df["volume"].idxmax())
# Out:
# 598

# %%
print(df["volume"].idxmin())
# Out:
# 151

# %%
print(df["volume"].std())
# Out:
# 14369091.49927283

# %%
df["volume"].plot(figsize=(10,5), title="Shopify Trading Volume Trend")
# Out:
# <AxesSubplot:title={'center':'Shopify Trading Volume Trend'}>

# %%
Q1 = df["volume"].quantile(0.25)
Q3 = df["volume"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# %%
anomalous_days = df[df["volume"] > upper_limit]

print(anomalous_days)
# Out:
#             date        open        high         low       close   adj_close  \
# 0     2015-05-21    2.800000    2.874000    2.411000    2.568000    2.568000
# 313   2016-08-17    3.890000    3.957000    3.860000    3.874000    3.874000
# 410   2017-01-05    4.447000    4.794000    4.425000    4.768000    4.768000
# 438   2017-02-15    5.487000    6.149000    5.430000    6.061000    6.061000
# 490   2017-05-02    8.041000    8.458000    7.757100    8.298000    8.298000
# ...          ...         ...         ...         ...         ...         ...
# 2128  2023-11-02   57.639999   60.150002   55.507000   59.700001   59.700001
# 2197  2024-02-13   77.800003   83.489998   77.010002   77.180000   77.180000
# 2256  2024-05-08   63.669998   64.199997   60.639999   62.730000   62.730000
# 2318  2024-08-07   64.500000   67.779999   63.549999   63.889999   63.889999
# 2386  2024-11-12  107.519997  114.510002  106.000000  108.919998  108.919998
#
# ...

# %%
mean_return = df["Daily_Return"].mean()
print("Mean Return:", mean_return)
# Out:
# Mean Return: 0.08655326042932378

# %%
variance_return = df["Daily_Return"].var()
print("Variance:", variance_return)
# Out:
# Variance: 9.733784022790234

# %%
std_return = df["Daily_Return"].std()
print("Standard Deviation:", std_return)
# Out:
# Standard Deviation: 3.119901284141893

# %%
df["Daily_Return"].plot(
    kind="hist",
    bins=20,
    title="Distribution of Shopify Daily Returns"
)
# Out:
# <AxesSubplot:title={'center':'Distribution of Shopify Daily Returns'}, ylabel='Frequency'>

# %%
df.to_csv("Cleaned ShopifyDataset.csv")
